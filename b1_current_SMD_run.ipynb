# %% [markdown]
# <a href="https://colab.research.google.com/github/Yibei990826/AnomalyDetection/blob/master/b1_current_SMD_run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install nixtla

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from nixtla import NixtlaClient
from utils import *

# %%
nixtla_client = NixtlaClient(
    # defaults to os.environ.get("NIXTLA_API_KEY")
    api_key = ''
)

# %%
SMD_full_df = pd.read_csv('SMD.csv')
X_df_SMD = SMD_full_df[['unique_id', 'ts', 'y']]
y_df_SMD = SMD_full_df[['unique_id', 'ts', 'label']]

# %%
# prompt: link to google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# anomalies_df_SMD = run_exp(X_df_SMD, level = 99, freq= 'T')

# %%
uids = X_df_SMD['unique_id'].unique().tolist()
preds = pd.DataFrame()
for sample_uids in uids:
    SMD_sub = X_df_SMD[X_df_SMD['unique_id']==sample_uids]
    preds = pd.concat([preds, run_exp(SMD_sub, level = 99, freq= 'T')], ignore_index=True)
# Out:
# Total series to be detected: 1
# now processing: machine-1-1_y_0
# Total series to be detected: 1
# now processing: machine-3-6_y_0
# Total series to be detected: 1
# now processing: machine-3-7_y_0
# Total series to be detected: 1
# now processing: machine-2-4_y_0
# Total series to be detected: 1
# now processing: machine-2-5_y_0
# Total series to be detected: 1
# now processing: machine-2-9_y_0
# Total series to be detected: 1
# now processing: machine-2-8_y_0
# Total series to be detected: 1
# now processing: machine-3-1_y_0
# Total series to be detected: 1
# now processing: machine-2-3_y_0
# Total series to be detected: 1
# now processing: machine-2-2_y_0
# Total series to be detected: 1
# now processing: machine-1-7_y_0
# Total series to be detected: 1
# now processing: machine-1-6_y_0
# Total series to be detected: 1
# now processing: machine-2-7_y_0
# Total series to be detected: 1
# now processing: machine-2-6_y_0
# Total series to be detected: 1
# ...

# %%
preds.to_csv('/content/drive/MyDrive/anomaly_detection/SMD_rst.csv')
